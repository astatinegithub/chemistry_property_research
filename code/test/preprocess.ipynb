# %%
import pandas as pd
from rdkit import Chem
from concurrent.futures import ProcessPoolExecutor

# %%
import os
print(os.getcwd())
# Out:
# d:\Repositories\chemical_properties\code

# %%
path = "d:/Repositories/chemical_properties/data/PubChem_compound_acetic_acid.csv"
ds = pd.read_csv(path)

# %%
ds.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1480566 entries, 0 to 1480565
# Data columns (total 9 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   Compound_CID       1480566 non-null  int64
#  1   Name               1480566 non-null  str
#  2   SMILES             1480566 non-null  str
#  3   Molecular_Weight   1480566 non-null  float64
#  4   Molecular_Formula  1480566 non-null  str
#  5   XLogP              1253685 non-null  float64
#  6   Charge             1480566 non-null  int64
#  7   Polar_Area         1480566 non-null  float64
#  8   Linked_BioAssays   61620 non-null    str
# dtypes: float64(3), int64(2), str(4)
# memory usage: 101.7 MB

# %%
df2 = ds.dropna()
df3 = ds[ds["Charge"] != 0]
df3.info()
df3.head()
# Out:
# <class 'pandas.DataFrame'>
# Index: 21213 entries, 1923 to 1480528
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Compound_CID       21213 non-null  int64
#  1   Name               21213 non-null  str
#  2   SMILES             21213 non-null  str
#  3   Molecular_Weight   21213 non-null  float64
#  4   Molecular_Formula  21213 non-null  str
#  5   XLogP              8530 non-null   float64
#  6   Charge             21213 non-null  int64
#  7   Polar_Area         21213 non-null  float64
#  8   Linked_BioAssays   391 non-null    str
# dtypes: float64(3), int64(2), str(4)
# memory usage: 1.6 MB
#        Compound_CID                                               Name  \
# 1923         439838                               Thiamine acetic acid
# 6801       73161883  Acetic acid;ditert-butyl-(2-phenylphenyl)phosp...
# 7620       21252148                                Acetate acetic acid
# ...

# %%
# def process(s):
#     return True if Chem.MolFromSmiles(s) is not None else False
# with ProcessPoolExecutor() as exeutor:
#     futuers = [exeutor.submit(process, i) for i in []]

# %%
df1 = ds.drop(["Linked_BioAssays"], axis=1)
df1 = df1.dropna()

df4 = df1.drop(["Compound_CID", "Name", "Molecular_Formula"], axis=1)
df4.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1253685 entries, 0 to 1480554
# Data columns (total 8 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   Compound_CID       1253685 non-null  int64
#  1   Name               1253685 non-null  str
#  2   SMILES             1253685 non-null  str
#  3   Molecular_Weight   1253685 non-null  float64
#  4   Molecular_Formula  1253685 non-null  str
#  5   XLogP              1253685 non-null  float64
#  6   Charge             1253685 non-null  int64
#  7   Polar_Area         1253685 non-null  float64
# dtypes: float64(3), int64(2), str(3)
# memory usage: 86.1 MB
# <class 'pandas.DataFrame'>
# Index: 1253685 entries, 0 to 1480554
# Data columns (total 5 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   SMILES            1253685 non-null  str
#  1   Molecular_Weight  1253685 non-null  float64
# ...

# %%
mask = df4["SMILES"].map(lambda s: Chem.MolFromSmiles(s) is not None)
dfF = df4[mask]
df4.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1253685 entries, 0 to 1480554
# Data columns (total 5 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   SMILES            1253685 non-null  str
#  1   Molecular_Weight  1253685 non-null  float64
#  2   XLogP             1253685 non-null  float64
#  3   Charge            1253685 non-null  int64
#  4   Polar_Area        1253685 non-null  float64
# dtypes: float64(3), int64(1), str(1)
# memory usage: 57.4 MB

# %%
df4.to_csv("D:/Repositories/chemical_properties/data/processed_dataset_5_property.csv")

# %%
df5 = df4.drop(["Charge"], axis=1)
df5.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1253685 entries, 0 to 1480554
# Data columns (total 4 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   SMILES            1253685 non-null  str
#  1   Molecular_Weight  1253685 non-null  float64
#  2   XLogP             1253685 non-null  float64
#  3   Polar_Area        1253685 non-null  float64
# dtypes: float64(3), str(1)
# memory usage: 47.8 MB
